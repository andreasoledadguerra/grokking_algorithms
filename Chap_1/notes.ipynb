# %% [markdown]
# # Chapter 1: Introduction to algorithms

# %% [markdown]
# ## Conceptual overview
#
# - Get foundation for the rest of the book.
# - Write the first search algorithm (binary search).
# - Learn how to talk about the running time of an algorithm (big O notation).

# %% [markdown]
# ## Key concepts
#
# - Binary search
# - Logarithms
# - Big O notation

# %% [markdown]
# ### Binary Search

# %%
def binary_search(arr, item):
    low = 0
    high = len(arr)-1 # low and high keep track of which part of the list you'll search in

    while low <= high: # while you haven't narrowed it down to one element
        mid = (low + high) // 2 # Check the middle element
        guess = arr[mid]
        if guess == item: # Found the item
            return mid
        elif guess > item: # The guess was too high
            high = mid - 1
        else:              # The guess was too low
            low = mid + 1
    return None            # The item doesn't exist


my_list = [1, 3, 5, 7, 9]

print(binary_search(my_list, 3)) # => 1
print(binary_search(my_list, -1)) # => None
# Out:
# 1
# None
